# %%
# Q1. Explain GET and POST methods.

# Ans.

# GET and POST methods are used to send data to the server.

# GET method is used to request data from a specifief resource
# GET method send data threw URL
# GET method send data in (key=value) pair

# POST mrthod is used to send data to server to create a resource
# In POST method data stored in body part of request

# %%
# Q2. Why is request used in Flask?

# Ans.

# request is used in flask to retirive data which is sent threw GET/POST method

# %%
# Q3. Why is redirect() used in Flask?

# Ans.

# redirect() is used for redirecting to other routes on the same application

# %%
# Q4. What are templates in Flask? Why is the render_template() function used?

# Ans.

# Templates are html files that contain static data as well as placeholders for dynamic data

# render_template() is used to generate output from a template file

# %%
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# Ans.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
