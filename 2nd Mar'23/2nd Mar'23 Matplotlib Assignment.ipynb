# %%
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# Ans.

# Matplotlib is a visulization library or plotting library
# This kind of library used for getting insights from data

# plot
# scatter
# bar
# barh
# pie
# hist

# %%
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# Ans.

# Scatter plot is use (.) to represent data

import numpy as np

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

import matplotlib.pyplot as plt

plt.title("Scatter plot")
plt.xlabel("This is x axis")
plt.ylabel("this is y axis")
plt.scatter(x,y)
plt.show()

# %%
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# subplot() is used to create multiple plots in single fugure

import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

fig, axes = plt.subplots(2, 2)

# Plot line 1
axes[0, 0].plot(x1, y1)
axes[0, 0].set_title('Line 1')

# Plot line 2
axes[0, 1].plot(x2, y2)
axes[0, 1].set_title('Line 2')

# Plot line 3
axes[1, 0].plot(x3, y3)
axes[1, 0].set_title('Line 3')

# Plot line 4
axes[1, 1].plot(x4, y4)
axes[1, 1].set_title('Line 4')

plt.tight_layout()

plt.show()

# %%
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# bar plot is a relationship between two axis's data

import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.title("Company vs Profit")
plt.xlabel('Company')
plt.ylabel("Profit")
plt.bar(company,profit)
plt.show()

plt.title("Company vs Profit")
plt.xlabel('Profit')
plt.ylabel("Company")
plt.barh(company,profit)
plt.show()

# %%
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Boxplots are a measure of how well distributed the data in a data set is.

plt.boxplot([box1,box2])
plt.show()
